# %%
from IPython.display import Image

# %% [markdown]
# # Διαγράμματα Μ-θ για όλες τις ανελαστικές αναλύσεις
#
# Χρησιμοποιούνται τα αποτελέσματα της επίλυσης με το Sap2000 και λαμβάνεται ενδεικτική κλίση στο φθίνοντα κλάδο (περισσότερες λεπτομέρειες στο [PEER/ATC-72-1](https://peer.berkeley.edu/sites/default/files/peer-atc-72-1_report.pdf) και σε video του PEER στο [youtube](https://www.youtube.com/watch?v=LyLaoU-FlLU)) σύμφωνα με τα σχήματα που ακολουθούν.

# %%
Image('sap/02_sap_user_hinge_col.png', width=600, height=400)

# %%
Image('sap/02_sap_user_hinge_beam.png', width=600, height=400)
