# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image

# %% [markdown]
# # Ανελαστική στατική ανάλυση με το SAP2000 v.14.2.4 - Αυτόματος υπολογισμός πλαστικών αρθρώσεων από τον οπλισμό των διατομών

# %% [markdown]
# ## Hinge properties

# %% [markdown]
# ### Στύλοι

# %%
Image('sap/01_sap_auto_hinge_col.png', width=600, height=400)

# %% [markdown]
# ### Δοκός

# %%
Image('sap/01_sap_auto_hinge_beam.png', width=600, height=400)

# %% [markdown]
# ## Καμπύλη αντίστασης

# %%
sap_curve = pd.read_excel('sap/01_sap_auto.xlsx', skiprows=[0,2], usecols=[0,1,2])
display(sap_curve.head(10))

sap_d = sap_curve['Displacement'].tolist()
sap_V = sap_curve['BaseForce'].tolist()
# Out:
#    Step  Displacement  BaseForce
# 0     0 -1.543000e-18      0.000
# 1     1  1.333000e-03     58.312
# 2     2  2.667000e-03    116.624
# 3     3  4.000000e-03    174.936
# 4     4  4.070000e-03    178.007
# 5     5  4.172000e-03    180.684
# 6     6  5.506000e-03    199.767
# 7     7  6.839000e-03    218.850
# 8     8  7.844000e-03    233.233
# 9     9  8.908000e-03    241.028

# %%
f, ax = plt.subplots(figsize=(10, 6))
ax.plot(sap_d, sap_V, label="sap2000_auto", lw=2)
# ax.plot(etabs_d, etabs_V, label="etabs", lw=2)
ax.axis([0, 0.20, 0, 1.2 * max(sap_V)])
ax.set_title('Καμπύλη αντίστασης')
ax.set_ylabel('V (kN)')
ax.set_xlabel('δ (m)')
ax.legend()
fig = (f, ax)
plt.show()

# %% [markdown]
# ## Διαγράμματα Μ-θ

# %% [markdown]
# ### Στύλος

# %%
Image('sap/01_sap_auto_hinge_col_results.png', width=600, height=400)

# %% [markdown]
# ### Δοκός - Αριστερά (Μ+)

# %%
Image('sap/01_sap_auto_hinge_beam_results_pos.png', width=600, height=400)

# %% [markdown]
# ### Δοκός - Δεξιά (Μ-)

# %%
Image('sap/01_sap_auto_hinge_beam_results_neg.png', width=600, height=400)
